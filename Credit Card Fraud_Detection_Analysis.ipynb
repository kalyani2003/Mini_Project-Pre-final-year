# %% [markdown]
# # Credit Card Fraud Detection Analysis

# %%
# STEPS TO DEVELOP CREDIT CARD FRAUD CLASSIFIER IN MACHINE LEARNING AS -
# 1) PERFORM EXPLORATORY DATA ANALYSIS (EDA) ON OUR DATASET
# 2) APPLY DIFFRENT MACHINE LEARNING ALGORITHMS TO OUR DATASET
# 3) TRAIN AND EVALUATE OUR MODELS ON THE DATASET AND PICK THE BEST ONE

# %%
# IMPORT LIBRARIES

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import gridspec

# %%
# LOAD THE DATASET FROM THE CSV FILEUSING PANDAS
# COPY THE PATH FOR THE CSV FILE

# 1) PERFORM EXPLORATORY DATA ANALYSIS (EDA) ON OUR DATASET

# %%
data = pd.read_csv(r"C:\Users\kalya\OneDrive\Desktop\mini project\creditcard.csv")

# %%
# >>>>> GRAB A PEEK AT THE DATA <<<<<

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
# >>>>> PRINT THE SHAPE OF THE DATA <<<<<<

# %%
print(data.shape)
# Out:
# (284807, 31)

# %%
# >>>>> DESCRIBE THE DATA <<<<<

# %%
data.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  3.918649e-15  5.682686e-16 -8.761736e-15  2.811118e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean  -1.552103e-15  2.040130e-15 -1.698953e-15 -1.893285e-16 -3.147640e-15
# ...

# %%
# >>>>> INFORMATION OF THE DATA <<<<<

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
# >>>>> ENDING DATA <<<<<

# %%
data.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
data.describe().transpose()
# Out:
#            count          mean           std         min           25%  \
# Time    284807.0  9.481386e+04  47488.145955    0.000000  54201.500000
# V1      284807.0  3.918649e-15      1.958696  -56.407510     -0.920373
# V2      284807.0  5.682686e-16      1.651309  -72.715728     -0.598550
# V3      284807.0 -8.761736e-15      1.516255  -48.325589     -0.890365
# V4      284807.0  2.811118e-15      1.415869   -5.683171     -0.848640
# V5      284807.0 -1.552103e-15      1.380247 -113.743307     -0.691597
# V6      284807.0  2.040130e-15      1.332271  -26.160506     -0.768296
# V7      284807.0 -1.698953e-15      1.237094  -43.557242     -0.554076
# V8      284807.0 -1.893285e-16      1.194353  -73.216718     -0.208630
# V9      284807.0 -3.147640e-15      1.098632  -13.434066     -0.643098
# V10     284807.0  1.772925e-15      1.088850  -24.588262     -0.535426
# V11     284807.0  9.289524e-16      1.020713   -4.797473     -0.762494
# ...

# %%
# >>>>> DETERMINE NUMBER OF FRAUD CASES IN DATASET <<<<<

# %%
fraud = data[data["Class"] ==1]
valid = data[data["Class"] == 0]
outlierFraction = len(fraud)/float(len(valid))
print(outlierFraction)
print("Fraud Cases:{}" .format(len(data[data["Class"] == 1])))
print ("Valid Transactions: {}".format(len(data[data["Class"] ==0])))
# Out:
# 0.0017304750013189597
# Fraud Cases:492
# Valid Transactions: 284315

# %%
# >>>>> PRINT THE AMOUNT DETAILS OF THE FRAUDULENT TRANSACTIONS <<<<<

# %%
print("Amount details of the fraudulent transactions")
fraud.Amount.describe()
# Out:
# Amount details of the fraudulent transactions
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
# >>>>> PRINT THE DETAILS FOR NORMAL TRANSACTIONS <<<<<

# %%
print("Details of valid transactions")
valid.Amount.describe()
# Out:
# Details of valid transactions
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
#>>>>> PLOTING THE CORRELATION MATRIX <<<<<

# %%
corrmat = data.corr()
fig = plt.figure(figsize = (12, 9))
sns.heatmap(corrmat, vmax = .8, square = True)
plt.show()

# %%
# DIVIDING THE X AND Y FRON THE DATASET

# %%
X = data .drop (['Class'], axis =1)
Y = data['Class']
print (X.shape)
print (Y.shape)

# (ITS A NUMPY ARRAY WITH NO COLUMNS)

xData = X.values
yData = Y.values
# Out:
# (284807, 30)
# (284807,)

# %%
# >>>>> STATISTICAL VIEW OF THE DATA <<<<<

# %%
sns.relplot(x = 'Amount', y="Time",hue="Class", data=data)

# %%
data.hist(figsize = (20,20))
plt.show()

# %% [markdown]
# # >>>>> CORRELATION MATRIX <<<<<

# %%
data_= data.iloc[:,1:29]
data_hd = data_.head(20)
data_hd.plot(kind ="hist",figsize = (16,8),grid = True)
plt.title("Histogram of (V1-V28) Top 20 Data")
plt.xlabel("Values of (V1-V28)")
plt.ylabel("Number of (V1-V28) Data")
# Out:
# Text(0, 0.5, 'Number of (V1-V28) Data')

# %%
sns.set(rc = {"figure.figsize" :(20,12)})
sns.displot(data_hd)
plt.title("Distplot of (V1-V28) Top 20 Data")
plt.xlabel("Values of (V1-V28)")
plt.ylabel("Number of (V1-V28) Data")
# Out:
# Text(18.309382986111117, 0.5, 'Number of (V1-V28) Data')

# %%
data_= data.iloc[:,1:29]
data_hd = data_.head(15)
data_hd.plot(kind ="line",figsize = (20,10),grid = True)
plt.title("Line Plot of (V1-V28) Top 15 Data")
plt.xlabel("Values of (V1-V28)")
plt.ylabel("Number of (V1-V28) Data")
# Out:
# Text(0, 0.5, 'Number of (V1-V28) Data')

# %%
data_= data.iloc[:,1:29]
data_hd = data_.head(20)
data_hd.plot(kind ="box",figsize = (20,10),grid = True)
plt.title("Box Plot of (V1-V28) Top 20 Data")
plt.xlabel("Values of (V1-V28)")
plt.ylabel("Number of (V1-V28) Data")
# Out:
# Text(0, 0.5, 'Number of (V1-V28) Data')

# %%
data_= data.iloc[:,1:11]
data_hd = data_.head(15)
data_hd.plot(kind ="bar",figsize = (17,7),grid = True)
plt.title("Bar Plot of (V1-V28) Top 15 Data")
# Out:
# Text(0.5, 1.0, 'Bar Plot of (V1-V28) Top 15 Data')

# %%
plt.figure(figsize = (10,6))
sns.regplot(x ="Class", y = "Amount", data = data,color ="black")
plt.title("Regression Plot of Class Vs Amount")
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.regplot(x ="Amount", y = "Time", data = data)
plt.title("Regression Plot of Amount Vs Time")
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.regplot(x ="Amount", y = "V1", data = data, color="red")
plt.title("Regression Plot of Amount Vs V1")
plt.show()

# %%
plt.figure(figsize = (10,6))
sns.regplot(x ="Amount", y = "V2", data = data, color="green")
plt.title("Regression Plot of Amount Vs V2")
plt.show()

# %%
# >>>>> Determining the Fraud Data Cases( finding outliers)

# %%
sns.countplot(data["Class"],palette ="magma")
plt.title("Valid Data Vs Fraud Data")
plt.show()
# Out:
# C:\Users\kalya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fraud_dt = data[data["Class"]==1]
valid_dt =  data[data["Class"]==0]

print("Fraud Cases:",len(fraud_dt))
print("Valid Cases:",len(fraud_dt))
# Out:
# Fraud Cases: 492
# Valid Cases: 492

# %%
outlier_fraction = len(fraud_dt)/len(valid_dt)
outlier_fraction
# Out:
# 0.0017304750013189597

# %% [markdown]
# # >>>>>  DATA PREPROCESSING  <<<<<

# %%
 #...............1)  SETTING X AND Y VARIABLES  .................

# %%
x = data.iloc[:,1:29]
x
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V19       V20  \
# ...

# %%
y = data.iloc[:,-1]
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
#............... 2) SPLITTING TRAIN AND TEST DATASET .................

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
x_train, x_test, y_train, y_test =train_test_split(x,y,random_state=42, test_size = 0.25)
print("Train Size = {}\nTest Size = {} \nTotal Size = {}".format(x_train.shape[0], x_test.shape[0],x.shape[0]))
# Out:
# Train Size = 213605
# Test Size = 71202
# Total Size = 284807

# %% [markdown]
# # >>>>>>> CONFUSION MATRIX <<<<<<<

# %%
#A confusion matrix is a performance measurement technique for Machine learning classification. 
#It is a kind of table which helps you to the know the performance of the classification model on a set of test data for that the true values are known. 
#The term confusion matrix itself is very simple, but its related terminology can be a little confusing. 
#Here, some simple explanation is given for this technique.

# %%
# The confusion matrix shows the ways in which your classification model is confused when

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_pred,y_test)
print(cm)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [51], in <cell line: 3>()
#       1 from sklearn.metrics import confusion_matrix
# ----> 3 cm = confusion_matrix(y_pred,y_test)
#       4 print(cm)
#
# NameError: name 'y_pred' is not defined

# %%
sns.set(rc ={"figure.figsize":(8,6)})
sns.heatmap(cm,annot=True, cmap="YLOrRd")

# %%
# RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier(n_estimators=100)
rfc

# %%
rfc.fit(x_train,y_train)

# %%
y_pred=rfc.predict(x_test)
y_pred

# %%
rfc_score=rfc.score(x_test,y_test)*100
print("Accuracy of the Credit Card data :",rfc_score)

# %% [markdown]
# # >>>>> MODEL BUILDING <<<<<<

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix

#  BU UISING 1) .....DECISION TREE

# %%
Data = DecisionTreeClassifier(max_depth =4, criterion ='entropy')
Data.fit(x_train, y_train)
tree_yhat = Data.predict(x_test)

# %%
# LETS CHECK THE ACCURACY OF OUR DECISION TREE MODEL

# %%
print("Accuracy score of the Decision Tree model is {}".format(accuracy_score(y_test, tree_yhat)))

# %%
# CHECKING F1 SCORE FOR THE DECISION TREE MODEL

# %%
print('F1 score of the Decision tree model is {}'. format(f1_score(y_test,tree_yhat)))

# %%
# CHECKING THE CONFUSION MATRIX

# %%
confusion_matrix(y_test,tree_yhat,labels =[0,1])

# %%
from sklearn.neighbors import KNeighborsClassifier

# 2) BY USING..... K- NEAREST NEIGHBORS

# %%
n =7
KNN = KNeighborsClassifier(n_neighbors =n)
KNN.fit(x_train, y_train)
knn_yhat = KNN, Data.predict(x_test)

# %%
# CHECK THE ACCURACY OF OUR K-NEAREST NEIGHBORS MODEL

# %%
print ("Accuracy score of the K-Nearest Neighbors model is {}".format(accuracy_score(y_test,knn_yhat)))

# %%
# CHECK F1-SCORE FOR THE K-NEAREST NEIGHBORS MODEL

# %%
print ("f1_score of the K-Nearest Neighbors model is {}". format(f1_score(y_test,knn_yhat)))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import ElasticNet
from sklearn.linear_model import Lasso

# 3) BY USING .......LOGISTIC REGRESSION

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
lr_yhat = lr.predict(x_test)

# %%
# CHECK THE ACCURACY OF OUR LOGISTIC REGREESION MODEL

# %%
print("Accuracy score of logistic Regression model is{}".format(accuracy_score (y_test,lr_yhat)))

# %%
#CHECK F1 - SCORE FOR THE LOGISTIC REGRESSION MODEL

# %%
print("F1 score of the logistic regression model is {}".format(f1_score(y_test,lr_yhat)))

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier

# 4) BY USING .......RANDOM FOREST

# %%
rf = RandomForestClassifier(max_depth =4)
rf.fit(x_train,y_train)
rf_yhat = rf.predict(x_test)

# %%
#CHECK ACCURACY OF OUR RANDOM FOREST MODEL

# %%
print("Accuracy score of the random forest model is{}".format(accuracy_score(y_test,rf_yhat)))

# %%
# CHECK F1-SCORE FOR THE RANDOM FOREST MODEL

# %%
print("F1 score of the RandomForest model is {}".format(f1_score(y_test,rf_yhat)))
